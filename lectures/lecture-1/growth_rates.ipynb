# %% [markdown]
# # Calculating growth rates from Kremer et al (2021)
# - n=40, g=(lny_2000-lny_1960)/40
# - n=10, g=(lny_1970-lny_1960)/10

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("c:\\Users\\nepoz\\yale\\spring26\\Economics-for-Global-Affairs\\globaleconomics\\class\\class_convergence.csv", sep='\t')

# %%
g40 = ((np.log(df.gdppc2000) - np.log(df.gdppc1960))/40)

# %%
g40.hist()
# Out:
# <Axes: >

# %%
print(g40.mean())
print(g40.std())
# Out:
# 0.01975233409698413
# 0.020310843807068834
